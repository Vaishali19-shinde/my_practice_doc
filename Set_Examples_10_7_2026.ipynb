# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishali19-shinde/my_practice_doc/blob/main/Set_Examples_10_7_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#set examples

# %%
#add a sinle element
colors={'red','green','blue'}
colors
# Out:
# {'blue', 'green', 'red'}

# %%
colors.add('pink')
colors
# Out:
# {'blue', 'green', 'pink', 'red'}

# %%
colors
# Out:
# {'blue', 'green', 'pink', 'red'}

# %%
#add a multiple element
colors.update(['yellow','orange'])
colors
# Out:
# {'blue', 'green', 'orange', 'pink', 'red', 'yellow'}

# %%
#remove an item from set (raises a KeyError if missing)
colors.remove('green')

# %%
colors
# Out:
# {'blue', 'orange', 'pink', 'red', 'yellow'}

# %%
colors.remove('green')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1280/721631182.py in <cell line: 0>()
# ----> 1 colors.remove('green')
#
# KeyError: 'green'

# %%
# Remove an item safely (does not throw an error if missing)
colors.discard('purple')
colors
# Out:
# {'blue', 'orange', 'pink', 'red', 'yellow'}

# %%
#Q.check item in present in set or not

set1={'flour','sugar','eggs'}
set1
# Out:
# {'eggs', 'flour', 'sugar'}

# %%
if 'sugar' in set1:
  print("present")
if 'icecream' not in set1:
  print("missing,we need it")
# Out:
# present
# missing,we need it

# %%
#iterate over set in
fruits={"apple","babana","mango"}
for i in fruits:
  print(i)
# Out:
# babana
# apple
# mango

# %%
#find n number of elements
even_number={2,4,6,8}
print(even_number)
print("length of n number of elements=",len(even_number))
# Out:
# {8, 2, 4, 6}
# length of n number of elements= 4

# %%
#copy method return a copy of the set
a={1,2,3,4,5}
new_set=a.copy()
print(new_set)
# Out:
# {1, 2, 3, 4, 5}
