# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishali19-shinde/my_practice_doc/blob/main/set_7_%26_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **#set & dictionary**

# %%
#both are mutable datatype
# at least one element inside

# %%
s={}
type(s)
# Out:
# dict

# %%
s1={2,2}
type(s1)
# Out:
# set

# %%
#features of set
#duplicate values are not allowed

# %%
p={1,2,3,4,5,5,5,4,3,1}
p
# Out:
# {1, 2, 3, 4, 5}

# %%
q={1,211,3,4,'A',89,67,'python'}
q
# Out:
# {1, 211, 3, 4, 67, 89, 'A', 'python'}

# %%
#Background data structure is hash table
#Hash table doent supporting indexing and slicing

# %%
#Set is mutable in nature

# %%
s={1,2,3,4,5,22,11,'A','Python','machine',34,23,12}
s
# Out:
# {1, 11, 12, 2, 22, 23, 3, 34, 4, 5, 'A', 'Python', 'machine'}

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {11, 12, 2, 22, 23, 3, 34, 4, 5, 'A', 'Python', 'machine'}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {11, 12, 22, 23, 3, 34, 4, 5, 'A', 'Python', 'machine'}

# %%
s.pop()
# Out:
# 3

# %%
s
# Out:
# {11, 12, 22, 23, 34, 4, 5, 'A', 'Python', 'machine'}

# %%
lot={1122,3344,5544,2233}

# %%
winner=lot.pop()

winner
# Out:
# 5544

# %%
lot1={11,22,3345,67}
print("original lot",lot1)
out=lot1.pop()
print("winner is ",out)
print("remaning lot",lot1)
# Out:
# original lot {11, 3345, 67, 22}
# winner is  11
# remaning lot {3345, 67, 22}

# %%
#remove
help(s.remove)
# Out:
# Help on built-in function remove:
#
# remove(...) method of builtins.set instance
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
s.remove(4)

# %%
s
# Out:
# {11, 12, 22, 23, 34, 5, 'A', 'Python', 'machine'}

# %%
s.remove(11)

# %%
s
# Out:
# {12, 22, 23, 34, 5, 'A', 'Python', 'machine'}

# %%
#if we try to remove an element which is not present

# %%
# s.remove(900) # This caused a KeyError because 900 was not in the set.
s.discard(900) # Use discard() to remove an element without raising an error if it's not present.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1065/3108153208.py in <cell line: 0>()
# ----> 1 s.remove(900)
#
# KeyError: 900

# %%
x={10,20,30}
x
# Out:
# {10, 20, 30}

# %%
x.pop()
# Out:
# 10

# %%
x
# Out:
# {20, 30}

# %%
x.remove(30)

# %%
x
# Out:
# {20}

# %%
#Q.create a empty set
empty_set=set()

# %%
type(empty_set)
# Out:
# set

# %%
set1={1,2,3,4,555,}
set
# Out:
# set

# %%
#add() method
set1.add("vaishali")
set1
# Out:
# {1, 2, 3, 4, 555, 'vaishali'}

# %%
#update() method

compony={"IBM","Infoosys","TCS"}
tech_company={"INFOTECH","GOOGLE","YAHOO","IBM"}
compony.update(tech_company)
compony
# Out:
# {'GOOGLE', 'IBM', 'INFOTECH', 'Infoosys', 'TCS', 'YAHOO'}

# %%
#discard()
language={"java","python","html"}
remove_lan=language.discard("java")
language
# Out:
# {'html', 'python'}
